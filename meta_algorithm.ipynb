# %% [markdown]
# ![image](images/algo.png)
#
# The setup of the algorithm is described in appendix B.6 (page 26)

# %%
# meta algo without learning
import numpy as np
from principal_meta import PrincipalMeta
from agent import Agent
from principal_agent_mdp import PrincipalAgentMDP

# %%
N_META = 2          # Inner/Outer Iterationen 2 in Figure 1 
GAMMA = 1

mdp = PrincipalAgentMDP(gamma=GAMMA)
agent = Agent(mdp)

# Principals reward function
r_p = np.zeros([mdp.n_states, mdp.n_outcomes])
for s in range(mdp.n_states):
    r_p[s, 0] = 14 / 9
    r_p[s, 1] = 0.0

# agent's reward already in MDP code


Q_bar_init = np.zeros((mdp.n_states, mdp.n_actions))

principal = PrincipalMeta(mdp, r_p, b_grid_step=0.1)
# Init
rho = {s: np.array([0.0, 0.0]) for s in range(mdp.n_states)} # for new agent
for meta in range(N_META):

    # Inner Optimization: Agent's learning
    V_agent, Q_agent, pi_star = agent.solve(rho)
    print(f"Agent V: {V_agent}")

    # Outer Optimization: Principal's learning 
    # Step 4: Outer – solve principal's MDP given pi
    rho_old = rho.copy()
    snapshots = principal.solve(agent)
    rho = principal.rho_star
    print(f"Contracts: {rho}")

    # Check convergence
    if all(np.allclose(rho[s], rho_old[s]) for s in range(mdp.n_states)):
        print("Meta-algorithm converged!")
        break

# Step 5: return (rho, pi)
print(f"\nFinal rho: {rho}")
print(f"Final pi:  {pi_star}")
# Out:
# Agent V: [0. 0. 0.]
# Agent policy: {0: 1, 1: 1, 2: 1}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 32
#      28
#      29     # Outer Optimization: Principal's learning
#      30     # Step 4: Outer – solve principal's MDP given pi
#      31     rho_old = rho.copy()
# ---> 32     snapshots = principal.solve(pi_dict)
#      33     rho = principal.rho_star
#      34     print(f"Contracts: {rho}")
#      35
#
# File ~/Desktop/FS2026/RL/rl_seminar/Seminar_RLDMUU_AI_agents_contracts/principal_meta.py:41, in PrincipalMeta.solve(self, pi_star, tol, max_iter, snapshot_every)
#      39 q_values = []
#      40 for b in self.contracts:
# ---> 41     a = pi_star(s, np.array(b))  # ← INSIDE loop
#      42     q = sum(
#      43         mdp.P_outcome[s, a, o] * (self.r_p[s, o] - b[o] + self.gamma * V[mdp.T(s, o)])
#      44         for o in range(self.n_outcomes)
#      45     )
#      46     q_values.append(q)
#
# TypeError: 'dict' object is not callable
