# %% [markdown]
# ![image](images/algo.png)
#
# The setup of the algorithm is described in appendix B.6 (page 26)

# %%
"""
Initialize the principal' s policy rho:
rho(s_1) = rho(s_2) = (0,0) 
The contract is denoted by the tuble b = (b(o_1),b(o_2))

Iteration 1: 
    Inner Optimization 
    Outer Optimization 
Iteration 2: 
    Inner optimization 
    Outer optimization     
"""
